# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import random
import timeit

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 772

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8900cf4136906365f29c764b12a540ce

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8900cf4136906365f29c764b12a540ce&q=Boston

# %%
# Create an empty list to hold weather data for each city
city_data = []
# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters and set them to 1
record_count = 1
set_count = 1
# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):     
    # Group cities in sets of 50 for logging purposes
    if (i % 100 == 0 and i >= 100):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),"Lat": city_lat,"Lng": city_lng,"Max Temp": city_max_temp, "Humidity": city_humidity,"Cloudiness": city_clouds,"Wind Speed": city_wind,"Country": city_country,"Description": city_weather_desc}) 

    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
    pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | stantsionno-oyashinskiy
# Processing Record 2 of Set 1 | tuy hoa
# Processing Record 3 of Set 1 | geraldton
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | goma
# Processing Record 9 of Set 1 | cherskiy
# Processing Record 10 of Set 1 | lerwick
# Processing Record 11 of Set 1 | cidreira
# Processing Record 12 of Set 1 | emba
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 16 of Set 1 | birobidzhan
# Processing Record 17 of Set 1 | pemangkat
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | klaksvik
# Processing Record 20 of Set 1 | tiksi
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | ribeira grande
# Processing Record 23 of Set 1 | clyde river
# Processing Record 24 of Set 1 | port elizabeth
# Processing Record 25 of Set 1 | tuktoyaktuk
# Processing Record 26 of Set 1 | yei
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | barraute
# Processing Record 29 of Set 1 | kodiak
# Processing Record 30 of Set 1 | harare
# Processing Record 31 of Set 1 | mataundh
# Processing Record 32 of Set 1 | buta
# Processing Record 33 of Set 1 | kalmunai
# Processing Record 34 of Set 1 | bengkulu
# Processing Record 35 of Set 1 | la ronge
# Processing Record 36 of Set 1 | hilo
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | hobart
# Processing Record 39 of Set 1 | ferrol
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | hithadhoo
# Processing Record 42 of Set 1 | acari
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | pimentel
# Processing Record 45 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 1 | victoria
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | talnakh
# Processing Record 49 of Set 1 | tuatapere
# Processing Record 50 of Set 1 | egvekinot
# Processing Record 51 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 52 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 53 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 54 of Set 1 | albany
# Processing Record 55 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 56 of Set 1 | castro
# Processing Record 57 of Set 1 | faanui
# Processing Record 58 of Set 1 | ha noi
# Processing Record 59 of Set 1 | praia da vitoria
# Processing Record 60 of Set 1 | marfino
# Processing Record 61 of Set 1 | nawa
# Processing Record 62 of Set 1 | senanga
# Processing Record 63 of Set 1 | pevek
# Processing Record 64 of Set 1 | iqaluit
# Processing Record 65 of Set 1 | port blair
# Processing Record 66 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 67 of Set 1 | chokurdakh
# Processing Record 68 of Set 1 | atuona
# Processing Record 69 of Set 1 | butaritari
# Processing Record 70 of Set 1 | marawi
# Processing Record 71 of Set 1 | mar del plata
# Processing Record 72 of Set 1 | uroteppa
# City not found. Skipping...
# Processing Record 73 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 74 of Set 1 | saint-philippe
# Processing Record 75 of Set 1 | new norfolk
# Processing Record 76 of Set 1 | avera
# Processing Record 77 of Set 1 | usinsk
# Processing Record 78 of Set 1 | isangel
# Processing Record 79 of Set 1 | dikson
# Processing Record 80 of Set 1 | bathsheba
# Processing Record 81 of Set 1 | shache
# Processing Record 82 of Set 1 | masuguru
# Processing Record 83 of Set 1 | korla
# Processing Record 84 of Set 1 | winterswijk
# Processing Record 85 of Set 1 | torbay
# Processing Record 86 of Set 1 | hirara
# Processing Record 87 of Set 1 | iringa
# Processing Record 88 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 89 of Set 1 | saint-augustin
# Processing Record 90 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 91 of Set 1 | auki
# Processing Record 92 of Set 1 | bossembele
# City not found. Skipping...
# Processing Record 93 of Set 1 | ponta do sol
# Processing Record 94 of Set 1 | qaanaaq
# Processing Record 95 of Set 1 | hermanus
# Processing Record 96 of Set 1 | nanortalik
# Processing Record 97 of Set 1 | takhtamygda
# Processing Record 98 of Set 1 | cockburn town
# Processing Record 99 of Set 1 | nouakchott
# Processing Record 100 of Set 1 | provideniya
# Processing Record 1 of Set 2 | lufilufi
# Processing Record 2 of Set 2 | silvan
# Processing Record 3 of Set 2 | coquimbo
# Processing Record 4 of Set 2 | jamestown
# Processing Record 5 of Set 2 | saint george
# Processing Record 6 of Set 2 | port alfred
# Processing Record 7 of Set 2 | taltal
# Processing Record 8 of Set 2 | upernavik
# Processing Record 9 of Set 2 | barrow
# Processing Record 10 of Set 2 | kavieng
# Processing Record 11 of Set 2 | bay roberts
# Processing Record 12 of Set 2 | tiarei
# Processing Record 13 of Set 2 | dingle
# Processing Record 14 of Set 2 | rio gallegos
# Processing Record 15 of Set 2 | east london
# Processing Record 16 of Set 2 | saskylakh
# Processing Record 17 of Set 2 | berehove
# Processing Record 18 of Set 2 | beoumi
# Processing Record 19 of Set 2 | nanticoke
# Processing Record 20 of Set 2 | apac
# Processing Record 21 of Set 2 | gimli
# Processing Record 22 of Set 2 | pitimbu
# Processing Record 23 of Set 2 | tabialan
# City not found. Skipping...
# Processing Record 24 of Set 2 | katsuura
# Processing Record 25 of Set 2 | flinders
# Processing Record 26 of Set 2 | itarema
# Processing Record 27 of Set 2 | sechura
# Processing Record 28 of Set 2 | ostrovnoy
# Processing Record 29 of Set 2 | yellowknife
# Processing Record 30 of Set 2 | ketchikan
# Processing Record 31 of Set 2 | majene
# Processing Record 32 of Set 2 | fairbanks
# Processing Record 33 of Set 2 | erzin
# Processing Record 34 of Set 2 | carnarvon
# Processing Record 35 of Set 2 | saint-pierre
# Processing Record 36 of Set 2 | buritis
# Processing Record 37 of Set 2 | vardo
# Processing Record 38 of Set 2 | cabo san lucas
# Processing Record 39 of Set 2 | sao filipe
# Processing Record 40 of Set 2 | sao pedro do sul
# Processing Record 41 of Set 2 | denizli
# Processing Record 42 of Set 2 | puerto quijarro
# Processing Record 43 of Set 2 | beringovskiy
# Processing Record 44 of Set 2 | vostok
# Processing Record 45 of Set 2 | haines junction
# Processing Record 46 of Set 2 | te anau
# Processing Record 47 of Set 2 | ulaangom
# Processing Record 48 of Set 2 | buala
# Processing Record 49 of Set 2 | alofi
# Processing Record 50 of Set 2 | khani
# Processing Record 51 of Set 2 | araouane
# Processing Record 52 of Set 2 | mbandaka
# Processing Record 53 of Set 2 | alta floresta
# Processing Record 54 of Set 2 | honolulu
# Processing Record 55 of Set 2 | simao dias
# Processing Record 56 of Set 2 | batagay-alyta
# Processing Record 57 of Set 2 | antalaha
# Processing Record 58 of Set 2 | sundsvall
# Processing Record 59 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 60 of Set 2 | port lincoln
# Processing Record 61 of Set 2 | avarua
# Processing Record 62 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 63 of Set 2 | ipixuna
# Processing Record 64 of Set 2 | norman wells
# Processing Record 65 of Set 2 | sungaipenuh
# Processing Record 66 of Set 2 | whitianga
# Processing Record 67 of Set 2 | wattegama
# Processing Record 68 of Set 2 | dubai
# Processing Record 69 of Set 2 | iquitos
# Processing Record 70 of Set 2 | arona
# Processing Record 71 of Set 2 | olafsvik
# Processing Record 72 of Set 2 | faya
# Processing Record 73 of Set 2 | salalah
# Processing Record 74 of Set 2 | raga
# Processing Record 75 of Set 2 | namibe
# Processing Record 76 of Set 2 | bambanglipuro
# Processing Record 77 of Set 2 | airai
# Processing Record 78 of Set 2 | mangan
# Processing Record 79 of Set 2 | camacha
# Processing Record 80 of Set 2 | cayenne
# Processing Record 81 of Set 2 | mehamn
# Processing Record 82 of Set 2 | villaviciosa
# Processing Record 83 of Set 2 | rolla
# Processing Record 84 of Set 2 | natal
# Processing Record 85 of Set 2 | yanam
# Processing Record 86 of Set 2 | nan
# Processing Record 87 of Set 2 | mahebourg
# Processing Record 88 of Set 2 | magnor
# Processing Record 89 of Set 2 | vinstra
# Processing Record 90 of Set 2 | yar-sale
# Processing Record 91 of Set 2 | yarada
# Processing Record 92 of Set 2 | naze
# Processing Record 93 of Set 2 | qeshm
# Processing Record 94 of Set 2 | launceston
# Processing Record 95 of Set 2 | changli
# Processing Record 96 of Set 2 | nicoya
# Processing Record 97 of Set 2 | richards bay
# Processing Record 98 of Set 2 | sabang
# Processing Record 99 of Set 2 | tacuarembo
# Processing Record 100 of Set 2 | adelaide
# Processing Record 1 of Set 3 | namatanai
# Processing Record 2 of Set 3 | noumea
# Processing Record 3 of Set 3 | buchanan
# Processing Record 4 of Set 3 | san cristobal
# Processing Record 5 of Set 3 | bambous virieux
# Processing Record 6 of Set 3 | ixtapa
# Processing Record 7 of Set 3 | bargarh
# Processing Record 8 of Set 3 | morondava
# Processing Record 9 of Set 3 | devils lake
# Processing Record 10 of Set 3 | ust-kuyga
# Processing Record 11 of Set 3 | kruszwica
# Processing Record 12 of Set 3 | burica
# City not found. Skipping...
# Processing Record 13 of Set 3 | sioux lookout
# Processing Record 14 of Set 3 | skibbereen
# Processing Record 15 of Set 3 | mporokoso
# Processing Record 16 of Set 3 | omboue
# Processing Record 17 of Set 3 | zhangjiakou
# Processing Record 18 of Set 3 | kaeo
# Processing Record 19 of Set 3 | powassan
# Processing Record 20 of Set 3 | meulaboh
# Processing Record 21 of Set 3 | ribas do rio pardo
# Processing Record 22 of Set 3 | georgetown
# Processing Record 23 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 3 | byron bay
# Processing Record 25 of Set 3 | iranshahr
# Processing Record 26 of Set 3 | antofagasta
# Processing Record 27 of Set 3 | san quintin
# Processing Record 28 of Set 3 | broken hill
# Processing Record 29 of Set 3 | arlit
# Processing Record 30 of Set 3 | hami
# Processing Record 31 of Set 3 | lata
# Processing Record 32 of Set 3 | iracoubo
# Processing Record 33 of Set 3 | abu samrah
# Processing Record 34 of Set 3 | kushiro
# Processing Record 35 of Set 3 | guerrero negro
# Processing Record 36 of Set 3 | tolaga bay
# Processing Record 37 of Set 3 | yazman
# Processing Record 38 of Set 3 | vilhena
# Processing Record 39 of Set 3 | marsa matruh
# Processing Record 40 of Set 3 | suhbaatar
# Processing Record 41 of Set 3 | buraydah
# Processing Record 42 of Set 3 | tasiilaq
# Processing Record 43 of Set 3 | innisfail
# Processing Record 44 of Set 3 | laguna
# Processing Record 45 of Set 3 | souillac
# Processing Record 46 of Set 3 | leningradskiy
# Processing Record 47 of Set 3 | thompson
# Processing Record 48 of Set 3 | upata
# Processing Record 49 of Set 3 | bubaque
# Processing Record 50 of Set 3 | genhe
# Processing Record 51 of Set 3 | katobu
# Processing Record 52 of Set 3 | serafimovich
# Processing Record 53 of Set 3 | mastic beach
# Processing Record 54 of Set 3 | hamilton
# Processing Record 55 of Set 3 | klyuchi
# Processing Record 56 of Set 3 | russell
# Processing Record 57 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 58 of Set 3 | khatanga
# Processing Record 59 of Set 3 | bilibino
# Processing Record 60 of Set 3 | safranbolu
# Processing Record 61 of Set 3 | portpatrick
# City not found. Skipping...
# Processing Record 62 of Set 3 | constitucion
# Processing Record 63 of Set 3 | rawson
# Processing Record 64 of Set 3 | bethel
# Processing Record 65 of Set 3 | santa helena
# Processing Record 66 of Set 3 | necochea
# Processing Record 67 of Set 3 | san patricio
# Processing Record 68 of Set 3 | fortuna
# Processing Record 69 of Set 3 | isiro
# Processing Record 70 of Set 3 | novoutkinsk
# Processing Record 71 of Set 3 | touros
# Processing Record 72 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 73 of Set 3 | altamirano
# Processing Record 74 of Set 3 | palasa
# Processing Record 75 of Set 3 | linqiong
# Processing Record 76 of Set 3 | zhongshu
# Processing Record 77 of Set 3 | valdivia
# Processing Record 78 of Set 3 | bud
# Processing Record 79 of Set 3 | hambantota
# Processing Record 80 of Set 3 | bage
# Processing Record 81 of Set 3 | mwene-ditu
# Processing Record 82 of Set 3 | batesville
# Processing Record 83 of Set 3 | cantapoy
# Processing Record 84 of Set 3 | tessalit
# Processing Record 85 of Set 3 | pushkino
# Processing Record 86 of Set 3 | vanavara
# Processing Record 87 of Set 3 | talaya
# Processing Record 88 of Set 3 | turayf
# Processing Record 89 of Set 3 | merauke
# Processing Record 90 of Set 3 | puerto madryn
# Processing Record 91 of Set 3 | rupert
# Processing Record 92 of Set 3 | penon blanco
# Processing Record 93 of Set 3 | shingu
# Processing Record 94 of Set 3 | loikaw
# Processing Record 95 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 96 of Set 3 | olinda
# Processing Record 97 of Set 3 | poum
# Processing Record 98 of Set 3 | pangnirtung
# Processing Record 99 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 100 of Set 3 | zainsk
# Processing Record 1 of Set 4 | longyearbyen
# Processing Record 2 of Set 4 | hovd
# Processing Record 3 of Set 4 | nelson bay
# Processing Record 4 of Set 4 | bandarban
# Processing Record 5 of Set 4 | zharkent
# Processing Record 6 of Set 4 | murgab
# Processing Record 7 of Set 4 | pirovskoye
# Processing Record 8 of Set 4 | nueva gerona
# Processing Record 9 of Set 4 | campoverde
# Processing Record 10 of Set 4 | la reforma
# Processing Record 11 of Set 4 | smidovich
# Processing Record 12 of Set 4 | vila velha
# Processing Record 13 of Set 4 | gualeguay
# Processing Record 14 of Set 4 | husainabad
# Processing Record 15 of Set 4 | kedougou
# Processing Record 16 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 17 of Set 4 | nikolskoye
# Processing Record 18 of Set 4 | lubango
# Processing Record 19 of Set 4 | simao
# Processing Record 20 of Set 4 | iguape
# Processing Record 21 of Set 4 | agadez
# Processing Record 22 of Set 4 | chake chake
# Processing Record 23 of Set 4 | boralday
# Processing Record 24 of Set 4 | bend
# Processing Record 25 of Set 4 | kudahuvadhoo
# Processing Record 26 of Set 4 | duz
# City not found. Skipping...
# Processing Record 27 of Set 4 | lavrentiya
# Processing Record 28 of Set 4 | kjollefjord
# Processing Record 29 of Set 4 | ancud
# Processing Record 30 of Set 4 | shawville
# Processing Record 31 of Set 4 | adrar
# Processing Record 32 of Set 4 | griffith
# Processing Record 33 of Set 4 | kendari
# Processing Record 34 of Set 4 | muzhi
# Processing Record 35 of Set 4 | broome
# Processing Record 36 of Set 4 | vershino-shakhtaminskiy
# Processing Record 37 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 4 | kamaishi
# Processing Record 39 of Set 4 | vizinga
# Processing Record 40 of Set 4 | seshcha
# Processing Record 41 of Set 4 | morrinhos
# Processing Record 42 of Set 4 | dauriya
# Processing Record 43 of Set 4 | teruel
# Processing Record 44 of Set 4 | tateyama
# Processing Record 45 of Set 4 | yibin
# Processing Record 46 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 47 of Set 4 | chuy
# Processing Record 48 of Set 4 | toppenish
# Processing Record 49 of Set 4 | prainha
# Processing Record 50 of Set 4 | dawei
# Processing Record 51 of Set 4 | champerico
# Processing Record 52 of Set 4 | sheridan
# Processing Record 53 of Set 4 | jeremie
# Processing Record 54 of Set 4 | tautira
# Processing Record 55 of Set 4 | alausi
# Processing Record 56 of Set 4 | baruun-urt
# Processing Record 57 of Set 4 | emporia
# Processing Record 58 of Set 4 | margate
# Processing Record 59 of Set 4 | sur
# Processing Record 60 of Set 4 | ostersund
# Processing Record 61 of Set 4 | koutiala
# Processing Record 62 of Set 4 | talara
# Processing Record 63 of Set 4 | tulum
# Processing Record 64 of Set 4 | itupiranga
# Processing Record 65 of Set 4 | birao
# Processing Record 66 of Set 4 | mahibadhoo
# Processing Record 67 of Set 4 | acurenam
# Processing Record 68 of Set 4 | nioro
# Processing Record 69 of Set 4 | kruisfontein
# Processing Record 70 of Set 4 | weyburn
# Processing Record 71 of Set 4 | feijo
# Processing Record 72 of Set 4 | hasaki
# Processing Record 73 of Set 4 | karratha
# Processing Record 74 of Set 4 | narsaq
# Processing Record 75 of Set 4 | vama buzaului
# City not found. Skipping...
# Processing Record 76 of Set 4 | jamkhed
# Processing Record 77 of Set 4 | san antonio
# Processing Record 78 of Set 4 | ambilobe
# Processing Record 79 of Set 4 | yokadouma
# Processing Record 80 of Set 4 | anadyr
# Processing Record 81 of Set 4 | voh
# Processing Record 82 of Set 4 | bandundu
# Processing Record 83 of Set 4 | neiafu
# Processing Record 84 of Set 4 | phuthaditjhaba
# Processing Record 85 of Set 4 | sainte-thecle
# Processing Record 86 of Set 4 | road town
# Processing Record 87 of Set 4 | saint-georges
# Processing Record 88 of Set 4 | birganj
# Processing Record 89 of Set 4 | west bay
# Processing Record 90 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 91 of Set 4 | thohoyandou
# Processing Record 92 of Set 4 | manokwari
# Processing Record 93 of Set 4 | itamarandiba
# Processing Record 94 of Set 4 | novyy urengoy
# Processing Record 95 of Set 4 | vestmannaeyjar
# Processing Record 96 of Set 4 | pout
# Processing Record 97 of Set 4 | kununurra
# Processing Record 98 of Set 4 | lebu
# Processing Record 99 of Set 4 | puquio
# Processing Record 100 of Set 4 | brownfield
# Processing Record 1 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 5 | ejido
# Processing Record 3 of Set 5 | eyl
# Processing Record 4 of Set 5 | hobyo
# Processing Record 5 of Set 5 | puteyets
# Processing Record 6 of Set 5 | izumo
# Processing Record 7 of Set 5 | waddan
# Processing Record 8 of Set 5 | torres
# Processing Record 9 of Set 5 | sambava
# Processing Record 10 of Set 5 | oranjemund
# Processing Record 11 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 12 of Set 5 | north myrtle beach
# Processing Record 13 of Set 5 | kathu
# Processing Record 14 of Set 5 | romanovo
# Processing Record 15 of Set 5 | lompoc
# Processing Record 16 of Set 5 | kenai
# Processing Record 17 of Set 5 | waris aliganj
# Processing Record 18 of Set 5 | taoudenni
# Processing Record 19 of Set 5 | copiapo
# Processing Record 20 of Set 5 | sabha
# Processing Record 21 of Set 5 | nemuro
# Processing Record 22 of Set 5 | mopti
# Processing Record 23 of Set 5 | alice springs
# Processing Record 24 of Set 5 | inegol
# Processing Record 25 of Set 5 | minab
# Processing Record 26 of Set 5 | kieta
# Processing Record 27 of Set 5 | emirdag
# Processing Record 28 of Set 5 | deputatskiy
# Processing Record 29 of Set 5 | katangli
# Processing Record 30 of Set 5 | eregli
# Processing Record 31 of Set 5 | pangai
# Processing Record 32 of Set 5 | sao jose da coroa grande
# Processing Record 33 of Set 5 | tevriz
# Processing Record 34 of Set 5 | gibara
# Processing Record 35 of Set 5 | qui nhon
# Processing Record 36 of Set 5 | bull savanna
# Processing Record 37 of Set 5 | gummidipundi
# Processing Record 38 of Set 5 | kahului
# Processing Record 39 of Set 5 | goderich
# Processing Record 40 of Set 5 | jiroft
# City not found. Skipping...
# Processing Record 41 of Set 5 | vila franca do campo
# Processing Record 42 of Set 5 | ahipara
# Processing Record 43 of Set 5 | boddam
# Processing Record 44 of Set 5 | ballina
# Processing Record 45 of Set 5 | codrington
# Processing Record 46 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 5 | owosso
# Processing Record 48 of Set 5 | esperance
# Processing Record 49 of Set 5 | xuddur
# Processing Record 50 of Set 5 | taunggyi
# Processing Record 51 of Set 5 | siocon
# Processing Record 52 of Set 5 | scarborough
# Processing Record 53 of Set 5 | correntina
# Processing Record 54 of Set 5 | sharjah
# Processing Record 55 of Set 5 | linqu
# Processing Record 56 of Set 5 | qaqortoq
# Processing Record 57 of Set 5 | severo-kurilsk
# Processing Record 58 of Set 5 | gigmoto
# Processing Record 59 of Set 5 | mentok
# City not found. Skipping...
# Processing Record 60 of Set 5 | chapais
# Processing Record 61 of Set 5 | matay
# Processing Record 62 of Set 5 | atbasar
# Processing Record 63 of Set 5 | miedzyrzec podlaski
# Processing Record 64 of Set 5 | nome
# Processing Record 65 of Set 5 | kavaratti
# Processing Record 66 of Set 5 | beba
# Processing Record 67 of Set 5 | priargunsk
# Processing Record 68 of Set 5 | dongsheng
# Processing Record 69 of Set 5 | saryozek
# Processing Record 70 of Set 5 | oyama
# Processing Record 71 of Set 5 | harigue
# City not found. Skipping...
# Processing Record 72 of Set 5 | port-gentil
# Processing Record 73 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 74 of Set 5 | pangody
# Processing Record 75 of Set 5 | kirakira
# Processing Record 76 of Set 5 | afikpo
# Processing Record 77 of Set 5 | aykhal
# Processing Record 78 of Set 5 | ksenyevka
# City not found. Skipping...
# Processing Record 79 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 80 of Set 5 | yongan
# Processing Record 81 of Set 5 | beloha
# Processing Record 82 of Set 5 | ware
# Processing Record 83 of Set 5 | bergen
# Processing Record 84 of Set 5 | vaitape
# Processing Record 85 of Set 5 | outlook
# Processing Record 86 of Set 5 | hofn
# Processing Record 87 of Set 5 | menongue
# Processing Record 88 of Set 5 | ciudad bolivar
# Processing Record 89 of Set 5 | fort-shevchenko
# Processing Record 90 of Set 5 | lasa
# Processing Record 91 of Set 5 | grindavik
# Processing Record 92 of Set 5 | diego de almagro
# Processing Record 93 of Set 5 | vanimo
# Processing Record 94 of Set 5 | bousso
# Processing Record 95 of Set 5 | aden
# Processing Record 96 of Set 5 | niamey
# Processing Record 97 of Set 5 | okhotsk
# Processing Record 98 of Set 5 | saint anthony
# Processing Record 99 of Set 5 | tabas
# Processing Record 100 of Set 5 | luderitz
# Processing Record 1 of Set 6 | villazon
# Processing Record 2 of Set 6 | dunedin
# Processing Record 3 of Set 6 | asau
# Processing Record 4 of Set 6 | kodinsk
# Processing Record 5 of Set 6 | walvis bay
# Processing Record 6 of Set 6 | skagastrond
# City not found. Skipping...
# Processing Record 7 of Set 6 | catia la mar
# Processing Record 8 of Set 6 | shetpe
# Processing Record 9 of Set 6 | treviglio
# Processing Record 10 of Set 6 | sistranda
# Processing Record 11 of Set 6 | qasigiannguit
# Processing Record 12 of Set 6 | porto empedocle
# Processing Record 13 of Set 6 | lander
# Processing Record 14 of Set 6 | srednekolymsk
# Processing Record 15 of Set 6 | kinkala
# Processing Record 16 of Set 6 | virginia beach
# Processing Record 17 of Set 6 | gushikawa
# Processing Record 18 of Set 6 | jadu
# Processing Record 19 of Set 6 | pozo colorado
# Processing Record 20 of Set 6 | lanzhou
# Processing Record 21 of Set 6 | grand island
# Processing Record 22 of Set 6 | college
# Processing Record 23 of Set 6 | novaya bryan
# Processing Record 24 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 25 of Set 6 | caravelas
# Processing Record 26 of Set 6 | harper
# Processing Record 27 of Set 6 | luba
# Processing Record 28 of Set 6 | cururupu
# Processing Record 29 of Set 6 | santa cruz
# Processing Record 30 of Set 6 | xucheng
# Processing Record 31 of Set 6 | pisco
# Processing Record 32 of Set 6 | fort nelson
# Processing Record 33 of Set 6 | quelimane
# Processing Record 34 of Set 6 | laerdalsoyri
# Processing Record 35 of Set 6 | arenapolis
# Processing Record 36 of Set 6 | juifang
# City not found. Skipping...
# Processing Record 37 of Set 6 | husavik
# Processing Record 38 of Set 6 | selfoss
# Processing Record 39 of Set 6 | dapdap
# Processing Record 40 of Set 6 | rincon
# Processing Record 41 of Set 6 | paamiut
# Processing Record 42 of Set 6 | samagaltay
# Processing Record 43 of Set 6 | rudbar
# Processing Record 44 of Set 6 | nouadhibou
# Processing Record 45 of Set 6 | khasan
# Processing Record 46 of Set 6 | ilulissat
# Processing Record 47 of Set 6 | saldanha
# Processing Record 48 of Set 6 | trindade
# Processing Record 49 of Set 6 | prado
# Processing Record 50 of Set 6 | borovskoy
# Processing Record 51 of Set 6 | kysyl-syr
# Processing Record 52 of Set 6 | sao felix do xingu
# Processing Record 53 of Set 6 | wodonga
# Processing Record 54 of Set 6 | shenzhen
# Processing Record 55 of Set 6 | harnosand
# Processing Record 56 of Set 6 | kidal
# Processing Record 57 of Set 6 | charlottetown
# Processing Record 58 of Set 6 | sarahan
# Processing Record 59 of Set 6 | teya
# Processing Record 60 of Set 6 | huilong
# Processing Record 61 of Set 6 | chom bung
# City not found. Skipping...
# Processing Record 62 of Set 6 | komsomolskiy
# Processing Record 63 of Set 6 | makakilo city
# Processing Record 64 of Set 6 | moose factory
# Processing Record 65 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 66 of Set 6 | sai buri
# Processing Record 67 of Set 6 | son la
# Processing Record 68 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 69 of Set 6 | gamba
# Processing Record 70 of Set 6 | karpogory
# Processing Record 71 of Set 6 | cananeia
# Processing Record 72 of Set 6 | kloulklubed
# Processing Record 73 of Set 6 | gat
# Processing Record 74 of Set 6 | staroderevyankovskaya
# Processing Record 75 of Set 6 | ouallam
# Processing Record 76 of Set 6 | port hardy
# Processing Record 77 of Set 6 | tabuk
# Processing Record 78 of Set 6 | matrei
# City not found. Skipping...
# Processing Record 79 of Set 6 | zeya
# Processing Record 80 of Set 6 | anloga
# Processing Record 81 of Set 6 | yuzhnyy
# Processing Record 82 of Set 6 | igarka
# Processing Record 83 of Set 6 | cockburn harbour
# City not found. Skipping...
# Processing Record 84 of Set 6 | koslan
# Processing Record 85 of Set 6 | coahuayana
# Processing Record 86 of Set 6 | victoria point
# Processing Record 87 of Set 6 | vao
# Processing Record 88 of Set 6 | medvezhyegorsk
# Processing Record 89 of Set 6 | labuhan
# Processing Record 90 of Set 6 | albury
# Processing Record 91 of Set 6 | panama city
# Processing Record 92 of Set 6 | matamoros
# Processing Record 93 of Set 6 | bayir
# Processing Record 94 of Set 6 | jibuti
# Processing Record 95 of Set 6 | mattru
# Processing Record 96 of Set 6 | embu
# Processing Record 97 of Set 6 | boyolangu
# Processing Record 98 of Set 6 | dickson
# Processing Record 99 of Set 6 | amga
# Processing Record 100 of Set 6 | luanda
# Processing Record 1 of Set 7 | lorengau
# Processing Record 2 of Set 7 | honiara
# Processing Record 3 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 7 | neuquen
# Processing Record 5 of Set 7 | nyzy
# Processing Record 6 of Set 7 | dedza
# Processing Record 7 of Set 7 | san andres
# Processing Record 8 of Set 7 | ponnampet
# Processing Record 9 of Set 7 | padang
# Processing Record 10 of Set 7 | cabedelo
# Processing Record 11 of Set 7 | kapit
# Processing Record 12 of Set 7 | tevaitoa
# Processing Record 13 of Set 7 | coatlan
# City not found. Skipping...
# Processing Record 14 of Set 7 | althofen
# Processing Record 15 of Set 7 | san pedro
# Processing Record 16 of Set 7 | nantucket
# Processing Record 17 of Set 7 | yeppoon
# Processing Record 18 of Set 7 | rajanpur
# Processing Record 19 of Set 7 | fukue
# Processing Record 20 of Set 7 | bandarbeyla
# Processing Record 21 of Set 7 | bundaberg
# Processing Record 22 of Set 7 | montepuez
# Processing Record 23 of Set 7 | sicamous
# Processing Record 24 of Set 7 | sorong
# Processing Record 25 of Set 7 | moussoro
# Processing Record 26 of Set 7 | plast
# Processing Record 27 of Set 7 | yatou
# Processing Record 28 of Set 7 | amuntai
# Processing Record 29 of Set 7 | ransang
# Processing Record 30 of Set 7 | yining
# Processing Record 31 of Set 7 | palmas de monte alto
# Processing Record 32 of Set 7 | mao
# Processing Record 33 of Set 7 | la libertad
# Processing Record 34 of Set 7 | quatre cocos
# Processing Record 35 of Set 7 | williams lake
# Processing Record 36 of Set 7 | karema
# Processing Record 37 of Set 7 | puerto maldonado
# Processing Record 38 of Set 7 | perpignan
# Processing Record 39 of Set 7 | cozumel
# Processing Record 40 of Set 7 | japura
# Processing Record 41 of Set 7 | farafangana
# Processing Record 42 of Set 7 | yumen
# Processing Record 43 of Set 7 | coruripe
# Processing Record 44 of Set 7 | mareeba
# Processing Record 45 of Set 7 | maarianhamina
# Processing Record 46 of Set 7 | kaitangata
# Processing Record 47 of Set 7 | half moon bay
# Processing Record 48 of Set 7 | bluefields
# Processing Record 49 of Set 7 | jalu
# Processing Record 50 of Set 7 | takaka
# Processing Record 51 of Set 7 | puerto leguizamo
# Processing Record 52 of Set 7 | santiago de cuba
# Processing Record 53 of Set 7 | gizo
# Processing Record 54 of Set 7 | acqui terme
# Processing Record 55 of Set 7 | pascoag
# Processing Record 56 of Set 7 | portland
# Processing Record 57 of Set 7 | kristiansund
# Processing Record 58 of Set 7 | mantua
# Processing Record 59 of Set 7 | olga
# Processing Record 60 of Set 7 | ramacca
# Processing Record 61 of Set 7 | aklavik
# Processing Record 62 of Set 7 | colares
# Processing Record 63 of Set 7 | mamakan
# Processing Record 64 of Set 7 | sorland
# Processing Record 65 of Set 7 | yulara
# Processing Record 66 of Set 7 | stornoway
# Processing Record 67 of Set 7 | carnduff
# Processing Record 68 of Set 7 | kizhinga
# Processing Record 69 of Set 7 | muroto
# Processing Record 70 of Set 7 | carutapera
# Processing Record 71 of Set 7 | shambu
# Processing Record 72 of Set 7 | iquique
# Processing Record 73 of Set 7 | tyukhtet
# Processing Record 74 of Set 7 | alamosa
# Processing Record 75 of Set 7 | vestmanna
# Processing Record 76 of Set 7 | rawah
# Processing Record 77 of Set 7 | barka kana
# Processing Record 78 of Set 7 | juneau
# Processing Record 79 of Set 7 | riyadh
# Processing Record 80 of Set 7 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 81 of Set 7 | nautla
# Processing Record 82 of Set 7 | alice
# Processing Record 83 of Set 7 | qena
# Processing Record 84 of Set 7 | mariel
# Processing Record 85 of Set 7 | swellendam
# Processing Record 86 of Set 7 | praia
# Processing Record 87 of Set 7 | gorontalo
# Processing Record 88 of Set 7 | mpika
# Processing Record 89 of Set 7 | san juan
# Processing Record 90 of Set 7 | pingzhuang
# Processing Record 91 of Set 7 | vytegra
# Processing Record 92 of Set 7 | trogir
# Processing Record 93 of Set 7 | mayo
# Processing Record 94 of Set 7 | mana
# Processing Record 95 of Set 7 | cam pha
# City not found. Skipping...
# Processing Record 96 of Set 7 | mount gambier
# Processing Record 97 of Set 7 | armacao dos buzios
# City not found. Skipping...
# Processing Record 98 of Set 7 | sinnamary
# Processing Record 99 of Set 7 | inirida
# Processing Record 100 of Set 7 | somerville
# Processing Record 1 of Set 8 | apollonia
# Processing Record 2 of Set 8 | dolores
# Processing Record 3 of Set 8 | kargasok
# Processing Record 4 of Set 8 | coaticook
# Processing Record 5 of Set 8 | onalaska
# Processing Record 6 of Set 8 | bilma
# Processing Record 7 of Set 8 | takoradi
# Processing Record 8 of Set 8 | wajima
# Processing Record 9 of Set 8 | vejalpur
# Processing Record 10 of Set 8 | ludvika
# Processing Record 11 of Set 8 | beyneu
# Processing Record 12 of Set 8 | ardmore
# Processing Record 13 of Set 8 | maracas
# Processing Record 14 of Set 8 | shimoni
# Processing Record 15 of Set 8 | charlestown
# Processing Record 16 of Set 8 | alyangula
# Processing Record 17 of Set 8 | kimbe
# Processing Record 18 of Set 8 | mabaruma
# Processing Record 19 of Set 8 | luang prabang
# Processing Record 20 of Set 8 | drumheller
# Processing Record 21 of Set 8 | eureka
# Processing Record 22 of Set 8 | karamken
# City not found. Skipping...
# Processing Record 23 of Set 8 | port augusta
# Processing Record 24 of Set 8 | melo
# Processing Record 25 of Set 8 | randolph
# Processing Record 26 of Set 8 | north bend
# Processing Record 27 of Set 8 | parras
# City not found. Skipping...
# Processing Record 28 of Set 8 | comodoro rivadavia
# Processing Record 29 of Set 8 | villarrica
# Processing Record 30 of Set 8 | warrington
# Processing Record 31 of Set 8 | palmer
# Processing Record 32 of Set 8 | baiao
# Processing Record 33 of Set 8 | virden
# Processing Record 34 of Set 8 | toora-khem
# Processing Record 35 of Set 8 | denpasar
# Processing Record 36 of Set 8 | imbituba
# Processing Record 37 of Set 8 | deleni
# Processing Record 38 of Set 8 | santa maria
# Processing Record 39 of Set 8 | northam
# Processing Record 40 of Set 8 | clinton
# Processing Record 41 of Set 8 | sibolga
# Processing Record 42 of Set 8 | plotnikovo
# Processing Record 43 of Set 8 | pierre
# Processing Record 44 of Set 8 | ozgon
# City not found. Skipping...
# Processing Record 45 of Set 8 | panjab
# Processing Record 46 of Set 8 | leshukonskoye
# Processing Record 47 of Set 8 | sompeta
# Processing Record 48 of Set 8 | muros
# Processing Record 49 of Set 8 | odienne
# Processing Record 50 of Set 8 | odweyne
# Processing Record 51 of Set 8 | upington
# Processing Record 52 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 53 of Set 8 | galveston
# Processing Record 54 of Set 8 | fuerte olimpo
# Processing Record 55 of Set 8 | manzhouli
# Processing Record 56 of Set 8 | yeehaw junction
# City not found. Skipping...
# Processing Record 57 of Set 8 | rabo de peixe
# Processing Record 58 of Set 8 | nago
# Processing Record 59 of Set 8 | hare bay
# Processing Record 60 of Set 8 | sola
# Processing Record 61 of Set 8 | barabai
# Processing Record 62 of Set 8 | oranjestad
# Processing Record 63 of Set 8 | bam
# Processing Record 64 of Set 8 | fukuma
# Processing Record 65 of Set 8 | linhares
# Processing Record 66 of Set 8 | jiblah
# Processing Record 67 of Set 8 | spring hill
# Processing Record 68 of Set 8 | verkhnyaya maksakovka
# Processing Record 69 of Set 8 | cranford
# Processing Record 70 of Set 8 | brownsville
# Processing Record 71 of Set 8 | trani
# Processing Record 72 of Set 8 | almaznyy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 716

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Stantsionno-Oyashinskiy  55.4664   83.8245     41.67        81          59
# 1                  Tuy Hoa  13.0833  109.3000     81.23        78          90
# 2                Geraldton -28.7667  114.6000     69.37        62          37
# 3                  Rikitea -23.1203 -134.9692     71.10        70          99
# 4                    Vaini -21.2000 -175.2000     77.16        78          75
# 5                  Ushuaia -54.8000  -68.3000     38.86        60           0
# 6                     Goma  -1.6792   29.2228     61.92        89          92
# 7                 Cherskiy  68.7500  161.3000     10.87        94          75
# 8                  Lerwick  60.1545   -1.1494     50.00        76         100
# 9                 Cidreira -30.1811  -50.2056     66.11        99         100
#
#    Wind Speed Country       Description
# 0        9.89      RU     broken clouds
# 1        9.89      VN   overcast clouds
# 2       14.74      AU  scattered clouds
# 3       19.44      PF   overcast clouds
# 4       16.11      TO     broken clouds
# 5        9.22      AR         clear sky
# 6        3.15      CD   overcast clouds
# 7        5.73      RU     broken clouds
# 8       22.48      GB   overcast clouds
# 9        5.73      BR   overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# Recreate the DataFrame by using the new column order
# Display sample data
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Description" ]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                       City Country      Lat       Lng  Max Temp  Humidity  \
# 0  Stantsionno-Oyashinskiy      RU  55.4664   83.8245     41.67        81
# 1                  Tuy Hoa      VN  13.0833  109.3000     81.23        78
# 2                Geraldton      AU -28.7667  114.6000     69.37        62
# 3                  Rikitea      PF -23.1203 -134.9692     71.10        70
# 4                    Vaini      TO -21.2000 -175.2000     77.16        78
# 5                  Ushuaia      AR -54.8000  -68.3000     38.86        60
# 6                     Goma      CD  -1.6792   29.2228     61.92        89
# 7                 Cherskiy      RU  68.7500  161.3000     10.87        94
# 8                  Lerwick      GB  60.1545   -1.1494     50.00        76
# 9                 Cidreira      BR -30.1811  -50.2056     66.11        99
#
#    Cloudiness  Wind Speed       Description
# 0          59        9.89     broken clouds
# 1          90        9.89   overcast clouds
# 2          37       14.74  scattered clouds
# 3          99       19.44   overcast clouds
# 4          75       16.11     broken clouds
# 5           0        9.22         clear sky
# 6          92        3.15   overcast clouds
# 7          75        5.73     broken clouds
# 8         100       22.48   overcast clouds
# 9         100        5.73   overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Country         object
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
